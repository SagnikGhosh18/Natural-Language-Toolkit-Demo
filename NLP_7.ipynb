# %% [markdown]
# # CHUNKING

# %%
import nltk

# %%
sentence = "the quick brown fox jumped over the lazy dog"

# %%
from nltk.tokenize import word_tokenize
tokens = word_tokenize(sentence)

# %%
print(tokens)
# Out:
# ['the', 'quick', 'brown', 'fox', 'jumped', 'over', 'the', 'lazy', 'dog']

# %%
tags = nltk.pos_tag(tokens)
print(tags)
# Out:
# [('the', 'DT'), ('quick', 'JJ'), ('brown', 'NN'), ('fox', 'NN'), ('jumped', 'VBD'), ('over', 'IN'), ('the', 'DT'), ('lazy', 'JJ'), ('dog', 'NN')]

# %%
grammar = "NP:{<DT>?<JJ>*<NN>}"

# %%
cp = nltk.RegexpParser(grammar)

# %%
result = cp.parse(tags)

# %%
print(result)
# Out:
# (S
#   (NP the/DT quick/JJ brown/NN)
#   (NP fox/NN)
#   jumped/VBD
#   over/IN
#   (NP the/DT lazy/JJ dog/NN))

# %%
result.draw()

# %% [markdown]
# ## for passage

# %%
#sentence tokenize
#word tokenize
#pos tag
#regex parse
#draw

#chunker in nltk

# %%
passage = "A Note about Witches. In fairy-tales, witches always wear silly black hats and black cloaks, and they ride on broomsticks. But this is not a fairy-tale. This is about REAL WITCHES. The most important thing you should know about REAL WITCHES is this. Listen very carefully. Never forget what is coming next. REAL WITCHES dress in ordinary clothes and look very much like ordinary women. They live in ordinary houses and they work in ORDINARY JOBS. That is why they are so hard to catch. A REAL WITCH hates children with a red-hot sizz-ling hatred that is more sizzling and red-hot than anyhatred you could possibly imagine. A REAL WITCH spends all her time plotting to get rid of the children in her particular territory. Her passion is to do away with them, one by one. It is all she thinks about the whole day long. Even if she is working as a cashier in a supermarket or typing letters for a businessman or driving round in a fancy car (and she could be doing any of these things), her mind will always be plotting and scheming and churning and burning and whiz-zing and phizzing with murderous bloodthirsty thoughts. 'Which child,' she says to herself all day long, 'exactly which child shall I choose for my next squelching?' A REAL WITCH gets the same pleasure from squel-ching a child asyou get from eating a plateful of strawberries and thick cream. She reckons on doing away with one child a week. Anything less than that and she becomes grumpy. One child a week is fifty-two a year." 
sentences = nltk.sent_tokenize(passage)
tagged_sentences = []
for sentence in sentences:
    words = nltk.word_tokenize(sentence)
    tags = nltk.pos_tag(words)
    tagged_sentences.append(tags)
    #print(tags)
    #print("\n")

# %%
for taggedSentence in tagged_sentences:
    result = cp.parse(taggedSentence)
    print(result)
    print("\n\n")
# Out:
# (S (NP A/DT Note/NN) about/IN Witches/NNP ./.)
#
#
#
# (S
#   In/IN
#   fairy-tales/NNS
#   ,/,
#   witches/NNS
#   always/RB
#   wear/VBP
#   silly/JJ
#   black/JJ
#   hats/NNS
#   and/CC
#   (NP black/JJ cloaks/NN)
#   ,/,
#   and/CC
#   they/PRP
#   ride/VBP
#   on/IN
#   broomsticks/NNS
#   ./.)
#
#
#
# (S But/CC this/DT is/VBZ not/RB a/DT fairy-tale/JJ ./.)
#
#
#
# (S This/DT is/VBZ about/IN REAL/JJ WITCHES/NNP ./.)
#
#
#
# (S
#   The/DT
#   most/RBS
#   (NP important/JJ thing/NN)
#   you/PRP
#   should/MD
#   know/VB
#   about/IN
#   REAL/JJ
#   WITCHES/NNP
#   is/VBZ
#   this/DT
#   ./.)
#
#
#
# (S Listen/VB very/RB carefully/RB ./.)
#
#
#
# (S Never/RB forget/VB what/WP is/VBZ coming/VBG next/RB ./.)
#
#
#
# (S
#   REAL/JJ
#   WITCHES/NNP
#   (NP dress/NN)
#   in/IN
#   ordinary/JJ
#   clothes/NNS
#   and/CC
#   look/VB
#   very/RB
#   much/RB
#   like/IN
#   ordinary/JJ
#   women/NNS
#   ./.)
#
#
#
# (S
#   They/PRP
#   live/VBP
#   in/IN
#   ordinary/JJ
#   houses/NNS
#   and/CC
#   they/PRP
#   work/VBP
#   in/IN
#   ORDINARY/NNP
#   JOBS/NNP
#   ./.)
#
#
#
# (S
#   That/DT
#   is/VBZ
#   why/WRB
#   they/PRP
#   are/VBP
#   so/RB
#   hard/JJ
#   to/TO
#   catch/VB
#   ./.)
#
#
#
# (S
#   A/DT
#   REAL/NNP
#   WITCH/NNP
#   hates/VBZ
#   children/NNS
#   with/IN
#   (NP a/DT red-hot/JJ sizz-ling/NN)
#   hatred/VBD
#   that/DT
#   is/VBZ
#   more/JJR
#   sizzling/JJ
#   and/CC
#   red-hot/JJ
#   than/IN
#   anyhatred/VBN
#   you/PRP
#   could/MD
#   possibly/RB
#   imagine/VB
#   ./.)
#
#
#
# (S
#   A/DT
#   REAL/NNP
#   WITCH/NNP
#   spends/VBZ
#   all/DT
#   her/PRP$
#   (NP time/NN)
#   plotting/VBG
#   to/TO
#   get/VB
#   rid/JJ
#   of/IN
#   the/DT
#   children/NNS
#   in/IN
#   her/PRP$
#   (NP particular/JJ territory/NN)
#   ./.)
#
#
#
# (S
#   Her/PRP$
#   (NP passion/NN)
#   is/VBZ
#   to/TO
#   do/VB
#   away/RP
#   with/IN
#   them/PRP
#   ,/,
#   one/CD
#   by/IN
#   one/CD
#   ./.)
#
#
#
# (S
#   It/PRP
#   is/VBZ
#   all/DT
#   she/PRP
#   thinks/VBZ
#   about/IN
#   (NP the/DT whole/JJ day/NN)
#   long/RB
#   ./.)
#
#
#
# (S
#   Even/RB
#   if/IN
#   she/PRP
#   is/VBZ
#   working/VBG
#   as/IN
#   (NP a/DT cashier/NN)
#   in/IN
#   (NP a/DT supermarket/NN)
#   or/CC
#   typing/VBG
#   letters/NNS
#   for/IN
#   (NP a/DT businessman/NN)
#   or/CC
#   driving/VBG
#   (NP round/NN)
#   in/IN
#   (NP a/DT fancy/JJ car/NN)
#   (/(
#   and/CC
#   she/PRP
#   could/MD
#   be/VB
#   doing/VBG
#   any/DT
#   of/IN
#   these/DT
#   things/NNS
#   )/)
#   ,/,
#   her/PRP$
#   (NP mind/NN)
#   will/MD
#   always/RB
#   be/VB
#   plotting/VBG
#   and/CC
#   scheming/VBG
#   and/CC
#   churning/VBG
#   and/CC
#   burning/VBG
#   and/CC
#   whiz-zing/JJ
#   and/CC
#   phizzing/VBG
#   with/IN
#   murderous/JJ
#   bloodthirsty/JJ
#   thoughts/NNS
#   ./.)
#
#
#
# (S
#   (NP 'Which/JJ child/NN)
#   ,/,
#   '/''
#   she/PRP
#   says/VBZ
#   to/TO
#   herself/VB
#   (NP all/DT day/NN)
#   long/RB
#   ,/,
#   'exactly/RB
#   which/WDT
#   child/VBP
#   shall/MD
#   I/PRP
#   choose/VB
#   for/IN
#   my/PRP$
#   (NP next/JJ squelching/NN)
#   ?/.
#   '/'')
#
#
#
# (S
#   A/DT
#   REAL/NNP
#   WITCH/NNP
#   gets/VBZ
#   (NP the/DT same/JJ pleasure/NN)
#   from/IN
#   squel-ching/VBG
#   (NP a/DT child/NN)
#   (NP asyou/NN)
#   get/VBP
#   from/IN
#   eating/VBG
#   (NP a/DT plateful/NN)
#   of/IN
#   strawberries/NNS
#   and/CC
#   (NP thick/JJ cream/NN)
#   ./.)
#
#
#
# (S
#   She/PRP
#   reckons/NNS
#   on/IN
#   doing/VBG
#   away/RB
#   with/IN
#   one/CD
#   (NP child/NN)
#   (NP a/DT week/NN)
#   ./.)
#
#
#
# (S
#   Anything/VBG
#   less/JJR
#   than/IN
#   that/DT
#   and/CC
#   she/PRP
#   becomes/VBZ
#   grumpy/JJ
#   ./.)
#
#
#
# (S
#   One/CD
#   (NP child/NN)
#   (NP a/DT week/NN)
#   is/VBZ
#   fifty-two/RBR
#   (NP a/DT year/NN)
#   ./.)
